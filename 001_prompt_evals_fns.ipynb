# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nimport json\nimport sys\n\ndef extract_instance_ids(text):\n    pattern = r'i-[0-9a-f]{17}'\n    matches = re.findall(pattern, text)\n    return matches\n\nif __name__ == \"__main__\":\n    input_text = sys.stdin.read()\n    instance_ids = extract_instance_ids(input_text)\n    print(json.dumps(instance_ids))\n",
#     "test_case": {
#       "task": "Extract AWS EC2 instance IDs from CloudTrail logs. Instance IDs follow the pattern 'i-' followed by 17 hexadecimal characters.",
#       "format": "regex"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly addresses the core requirement with a simple, functional regex pattern. However, the case-sensitivity issue is a critical flaw since real AWS EC2 instance IDs may contain uppercase hexadecimal characters. Additionally, production code parsing CloudTrail logs should include error handling and likely deduplication for practical use. The pattern accuracy is good, but robustness is lacking."
#   },
#   {
#     "output": "\nimport json\nimport re\n\ndef parse_lambda_config(config_input):\n    \"\"\"Parse AWS Lambda function configuration and extract key details.\"\"\"\n    \n    if isinstance(config_input, str):\n        try:\n            config = json.loads(config_input)\n        except json.JSONDecodeError:\n            config = config_input\n    else:\n        config = config_input\n    \n    result = {\n        \"environment_variables\": {},\n        \"handler\": None,\n        \"timeout\": None\n    }\n    \n    if isinstance(config, dict):\n        if \"Environment\" in config and \"Variables\" in config[\"Environment\"]:\n            result[\"environment_variables\"] = config[\"Environment\"][\"Variables\"]\n        \n        if \"Handler\" in config:\n            result[\"handler\"] = config[\"Handler\"]\n        \n        if \"Timeout\" in config:\n            result[\"timeout\"] = config[\"Timeout\"]\n    \n    elif isinstance(config, str):\n        handler_match = re.search(r'\"Handler\"\\s*:\\s*\"([^\"]+)\"', config)\n        if handler_match:\n            result[\"handler\"] = handler_match.group(1)\n        \n        timeout_match = re.search(r'\"Timeout\"\\s*:\\s*(\\d+)', config)\n        if timeout_match:\n            result[\"timeout\"] = int(timeout_match.group(1))\n        \n        env_match = re.search(r'\"Variables\"\\s*:\\s*({[^}]+})', config)\n        if env_match:\n            try:\n                result[\"environment_variables\"] = json.loads(env_match.group(1))\n            except json.JSONDecodeError:\n                var_pattern = r'\"([^\"]+)\"\\s*:\\s*\"([^\"]*)\"'\n                matches = re.findall(var_pattern, env_match.group(1))\n                result[\"environment_variables\"] = {k: v for k, v in matches}\n    \n    return result\n\n\nif __name__ == \"__main__\":\n    test_config = {\n        \"FunctionName\": \"my-function\",\n        \"Handler\": \"index.handler\",\n        \"Timeout\": 30,\n        \"Environment\": {\n            \"Variables\": {\n                \"DB_HOST\": \"localhost\",\n                \"DB_PORT\": \"5432\",\n                \"ENV\": \"production\"\n            }\n        }\n    }\n    \n    result = parse_lambda_config(test_config)\n    print(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS Lambda function configuration and extract the environment variables, handler name, and timeout value into a structured format.",
#       "format": "json"
#     },
#     "score": 3.0,
#     "reasoning": "The solution correctly addresses the core task for well-formed dictionary inputs and demonstrates understanding of the problem. However, the string parsing fallback using regex is a significant weakness that limits robustness. The approach of attempting JSON parsing first is sound, but relying on regex for structured data extraction introduces brittleness and maintenance concerns. While the code works for the provided test case, it would fail on realistic AWS configurations with complex environment variable values or minor formatting variations. Better approaches would include using a proper JSON parser with error handling or leveraging boto3 for actual AWS Lambda configurations."
#   },
#   {
#     "output": "\nimport re\n\ndef is_valid_s3_bucket_name(bucket_name: str) -> bool:\n    pattern = r'^[a-z0-9][a-z0-9\\-]*[a-z0-9]$|^[a-z0-9]$'\n    \n    if not isinstance(bucket_name, str):\n        return False\n    \n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    if not re.match(pattern, bucket_name):\n        return False\n    \n    if '..' in bucket_name:\n        return False\n    \n    if bucket_name.startswith('-') or bucket_name.endswith('-'):\n        return False\n    \n    return True\n",
#     "test_case": {
#       "task": "Write a Python function that takes an S3 bucket name and returns True if it follows AWS naming conventions (lowercase, no underscores, 3-63 characters), False otherwise.",
#       "format": "python"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly implements most core AWS S3 naming conventions but includes redundant validation logic that makes the code harder to maintain. The regex pattern with alternation is overcomplicated since `^[a-z0-9][a-z0-9\\-]*[a-z0-9]$` already matches strings of 2+ characters with proper dash placement, while `^[a-z0-9]$` for single chars is subsumed by allowing 3-63 length only. More critically, it misses the AWS rule prohibiting bucket names that look like IP addresses (four dot-separated numeric parts). While the function will work for typical valid bucket names, the code quality could be improved through simplification and the completeness against AWS spec is questionable."
#   }
# ]
