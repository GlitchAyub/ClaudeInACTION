# %%
#install dependencies
# %pip install anthropic python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#LOAD ENV
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#Create API CLient

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages,system=None):
    params = {
        "model":model,
        "max_tokens":1000,
        "messages":messages,
     
    }
    if system:
        params["system"]=system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []
system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
add_user_message(messages,"how do i solve 5x+3=2 for x ?")
answer = chat(messages,system=system_prompt)

answer
# Out:
# 'To solve 5x + 3 = 2 for x, I need to isolate x by using inverse operations.\n\n**Step 1:** Subtract 3 from both sides\n5x + 3 - 3 = 2 - 3\n5x = -1\n\n**Step 2:** Divide both sides by 5\n5x ÷ 5 = -1 ÷ 5\nx = -1/5\n\n**Answer:** x = -1/5 (or -0.2 as a decimal)\n\n**Check:** Let me verify by substituting back into the original equation:\n5(-1/5) + 3 = -1 + 3 = 2 ✓'

# %%
messages = []

add_user_message(messages,"write a Python  function that checks a string for a dublicate character")
answer = chat(messages,system="You are a Python Engineer who writes very consise code")

answer
# Out:
# '```python\ndef has_duplicate(s):\n    return len(s) != len(set(s))\n```\n\nThis function converts the string to a set (which removes duplicates) and compares lengths. If they differ, duplicates exist.'

# %%
messages = []
def chatwa(messages,temperature = 1.0):
   

    message = client.messages.create(       model=model,
        max_tokens=1000,
        messages=messages,
         temperature=temperature)
    return message.content[0].text

add_user_message(messages,"give me a movie idea")
answer = chatwa(messages,temperature=0.0)

answer
# Out:
# '**Title: "The Memory Thief"**\n\n**Genre:** Sci-fi Thriller\n\n**Premise:** \nIn 2035, a black market "memory surgeon" named Maya makes a living extracting and selling people\'s memories—helping trauma victims forget their pain, or allowing the wealthy to experience someone else\'s adventures. But when she accidentally steals a memory containing evidence of a massive conspiracy, she becomes the target of both corporate assassins and government agents.\n\nThe twist: Maya discovers the memory isn\'t from a client—it\'s her own suppressed memory of witnessing a murder as a child. Now she must decide whether to sell her most valuable memory and forget forever, or keep it and fight back against the people who\'ve been controlling her life from the shadows.\n\n**Tone:** Think "Eternal Sunshine of the Spotless Mind" meets "The Bourne Identity"—exploring themes of identity, trauma, and whether some things are worth remembering even when they hurt.\n\nWould you like me to develop this furthe
# ...
